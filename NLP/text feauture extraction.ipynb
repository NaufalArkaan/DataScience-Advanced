# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('../Pengenalan/DS Dataset Mahir/smsspamcollection.tsv', sep='\t')

# %%
df.head(10)
# Out:
#   label                                            message  length  punct
# 0   ham  Go until jurong point, crazy.. Available only ...     111      9
# 1   ham                      Ok lar... Joking wif u oni...      29      6
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     155      6
# 3   ham  U dun say so early hor... U c already then say...      49      6
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61      2
# 5  spam  FreeMsg Hey there darling it's been 3 week's n...     147      8
# 6   ham  Even my brother is not like to speak with me. ...      77      2
# 7   ham  As per your request 'Melle Melle (Oru Minnamin...     160      6
# 8  spam  WINNER!! As a valued network customer you have...     157      6
# 9  spam  Had your mobile 11 months or more? U R entitle...     154      2

# %%
#membuat fitur
x = df['message']
y = df['label']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
countvec = CountVectorizer()

# %%
x_train_count = countvec.fit_transform(x_train)

# %%
x_train
# Out:
# 3235                                  Yup ü not comin :-(
# 945     I sent my scores to sophas and i had to do sec...
# 5319                         Kothi print out marandratha.
# 5528    Its just the effect of irritation. Just ignore it
# 247                        I asked you to call him now ok
#                               ...
# 3772    Hi, wlcome back, did wonder if you got eaten b...
# 5191                               Sorry, I'll call later
# 5226        Prabha..i'm soryda..realy..frm heart i'm sory
# 5390                           Nt joking seriously i told
# 860               Did he just say somebody is named tampa
# Name: message, Length: 3733, dtype: object

# %%
x_train_count
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 49992 stored elements and shape (3733, 7082)>

# %%
x_train.shape
# Out:
# (3733,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# %%
x_train_tfidf  = vectorizer.fit_transform(x_train)

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC()
clf.fit(x_train_tfidf, y_train)
# Out:
# LinearSVC()

# %%
x_test_tfidf = vectorizer.fit_transform(x_test)

# %%
x_test_tfidf
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 24177 stored elements and shape (1839, 4695)>

# %%
prediction = clf.predict(x_test_tfidf)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 prediction = clf.predict(x_test_tfidf)
#
# File c:\CodingProjects\DataScience-ITBOX\DS-Advanced\.venv\Lib\site-packages\sklearn\linear_model\_base.py:375, in LinearClassifierMixin.predict(self, X)
#     361 """
#     362 Predict class labels for samples in X.
#     363
#    (...)    372     Vector containing the class labels for each sample.
#     373 """
#     374 xp, _ = get_namespace(X)
# --> 375 scores = self.decision_function(X)
#     376 if len(scores.shape) == 1:
#     377     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File c:\CodingProjects\DataScience-ITBOX\DS-Advanced\.venv\Lib\site-packages\sklearn\linear_model\_base.py:352, in LinearClassifierMixin.decision_function(self, X)
#     349 check_is_fitted(self)
#     350 xp, _ = get_namespace(X)
# ...

# %%
from sklearn.pipeline import Pipeline

# %%
text_clf = Pipeline([('tfidf',TfidfVectorizer()), ('clf', LinearSVC())])

# %%
text_clf.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('clf', LinearSVC())])

# %%
prediction = text_clf.predict(x_test)

# %%
from sklearn import metrics
print(metrics.confusion_matrix(y_test, prediction))
print(metrics.classification_report(y_test, prediction))
print(metrics.accuracy_score(y_test, prediction))
# Out:
# [[1586    7]
#  [  12  234]]
#               precision    recall  f1-score   support
#
#          ham       0.99      1.00      0.99      1593
#         spam       0.97      0.95      0.96       246
#
#     accuracy                           0.99      1839
#    macro avg       0.98      0.97      0.98      1839
# weighted avg       0.99      0.99      0.99      1839
#
# 0.989668297988037

# %%
text_clf.predict(["Congratulation! You are the winner! Call out number 12345 to get your prize RIGHT Now"])
# Out:
# array(['spam'], dtype=object)

# %%
text_clf.predict(["Hey please call me now, i need to talk to you"])
# Out:
# array(['ham'], dtype=object)
