# %%
import pandas as pd

# %%
#Import Data
Trset = pd.read_csv("./DS Dataset Mahir/TrSet.csv")

# %%
Trset
# Out:
#          CUST_NO       VTG   AGETIER EDUCATION_DESC GENDER    EOP_BAL_CS  \
# 0      2730505.6  16-20 th  21-30 th    UNIVERSITAS      P  2.056059e+07
# 1      2734315.2  16-20 th  41-50 th    UNIVERSITAS      L  9.170948e+05
# 2      2668305.2  16-20 th  41-50 th    UNIVERSITAS      L  4.300652e+05
# 3      2526375.6  16-20 th  41-50 th    UNIVERSITAS      L  4.348930e+06
# 4      2437968.4  16-20 th  51-65 th            SMA      L  6.702202e+07
# ...          ...       ...       ...            ...    ...           ...
# 43621  7749589.4      1 th  21-30 th            SMA      L  9.897000e+05
# 43622  7801324.8      1 th  31-40 th        AKADEMI      P  8.365746e+06
# 43623  7803506.8      1 th  21-30 th    UNIVERSITAS      L  2.424743e+07
# 43624  4734476.0   6-10 th  31-40 th            SMA      L  1.670087e+07
# 43625  3639642.0  11-15 th  51-65 th             SD      L  5.242412e+08
#
#        MTH_AVG_BAL_CS  MTH6_AVG_BAL_CS  DELTA_FUNDING_BALANCE  \
# ...

# %%
Trset.head(9)
# Out:
#      CUST_NO       VTG   AGETIER EDUCATION_DESC GENDER    EOP_BAL_CS  \
# 0  2730505.6  16-20 th  21-30 th    UNIVERSITAS      P  2.056059e+07
# 1  2734315.2  16-20 th  41-50 th    UNIVERSITAS      L  9.170948e+05
# 2  2668305.2  16-20 th  41-50 th    UNIVERSITAS      L  4.300652e+05
# 3  2526375.6  16-20 th  41-50 th    UNIVERSITAS      L  4.348930e+06
# 4  2437968.4  16-20 th  51-65 th            SMA      L  6.702202e+07
# 5  2390138.2  16-20 th  31-40 th    UNIVERSITAS      L  1.485426e+08
# 6  2330060.0  16-20 th  31-40 th            SMA      P  1.171279e+06
# 7  1517175.0  16-20 th  41-50 th            SMA      L  3.296138e+07
# 8  1036137.0   > 20 th  51-65 th        AKADEMI      P  3.503638e+07
#
#    MTH_AVG_BAL_CS  MTH6_AVG_BAL_CS  DELTA_FUNDING_BALANCE  MTH_AVG_BAL_IDR  \
# 0    1.984331e+07     8.539044e+06          -1.348543e+07     1.984331e+07
# 1    2.694370e+06     1.951391e+07           3.405224e+07     2.694370e+06
# ...

# %%
Trset[['VTG', 'GENDER']].head()
# Out:
#         VTG GENDER
# 0  16-20 th      P
# 1  16-20 th      L
# 2  16-20 th      L
# 3  16-20 th      L
# 4  16-20 th      L

# %%
Trset.iloc[1,4]
# Out:
# 'L'

# %%
Trset.iloc[1:5, 1:4] #1:5 = ambil baris indeks ke-1 sampai ke-4 (karena slicing di Python stop exclusive, jadi indeks 5 tidak ikut). 1:4 = ambil kolom indeks ke-1 sampai ke-3.
# Out:
#         VTG   AGETIER EDUCATION_DESC
# 1  16-20 th  41-50 th    UNIVERSITAS
# 2  16-20 th  41-50 th    UNIVERSITAS
# 3  16-20 th  41-50 th    UNIVERSITAS
# 4  16-20 th  51-65 th            SMA

# %%
Trset.iloc[:, 3]
# Out:
# 0        UNIVERSITAS
# 1        UNIVERSITAS
# 2        UNIVERSITAS
# 3        UNIVERSITAS
# 4                SMA
#             ...
# 43621            SMA
# 43622        AKADEMI
# 43623    UNIVERSITAS
# 43624            SMA
# 43625             SD
# Name: EDUCATION_DESC, Length: 43626, dtype: object

# %%
dfCustNo = Trset[["CUST_NO"]]

# %%
dfCustNo.head()
# Out:
#      CUST_NO
# 0  2730505.6
# 1  2734315.2
# 2  2668305.2
# 3  2526375.6
# 4  2437968.4

# %%
Trset.head()
# Out:
#      CUST_NO       VTG   AGETIER EDUCATION_DESC GENDER   EOP_BAL_CS  \
# 0  2730505.6  16-20 th  21-30 th    UNIVERSITAS      P  20560590.01
# 1  2734315.2  16-20 th  41-50 th    UNIVERSITAS      L    917094.84
# 2  2668305.2  16-20 th  41-50 th    UNIVERSITAS      L    430065.24
# 3  2526375.6  16-20 th  41-50 th    UNIVERSITAS      L   4348929.80
# 4  2437968.4  16-20 th  51-65 th            SMA      L  67022018.69
#
#    MTH_AVG_BAL_CS  MTH6_AVG_BAL_CS  DELTA_FUNDING_BALANCE  MTH_AVG_BAL_IDR  \
# 0    1.984331e+07     8.539044e+06          -1.348543e+07     1.984331e+07
# 1    2.694370e+06     1.951391e+07           3.405224e+07     2.694370e+06
# 2    1.719333e+06     1.974608e+06           7.410419e+05     1.719333e+06
# 3    1.373424e+06     1.874303e+06           1.571728e+06     1.373424e+06
# 4    1.855625e+08     2.803859e+08           4.921136e+08     1.855625e+08
#
#    ...  AVG_CREDIT_3MTH  SUM_CREDIT_LESS_3MIL  SUM_CREDIT_ZERO  \
# ...

# %%
Trset = Trset.drop("GENDER", axis=1)

# %%
Trset.head()
# Out:
#      CUST_NO       VTG   AGETIER EDUCATION_DESC   EOP_BAL_CS  MTH_AVG_BAL_CS  \
# 0  2730505.6  16-20 th  21-30 th    UNIVERSITAS  20560590.01    1.984331e+07
# 1  2734315.2  16-20 th  41-50 th    UNIVERSITAS    917094.84    2.694370e+06
# 2  2668305.2  16-20 th  41-50 th    UNIVERSITAS    430065.24    1.719333e+06
# 3  2526375.6  16-20 th  41-50 th    UNIVERSITAS   4348929.80    1.373424e+06
# 4  2437968.4  16-20 th  51-65 th            SMA  67022018.69    1.855625e+08
#
#    MTH6_AVG_BAL_CS  DELTA_FUNDING_BALANCE  MTH_AVG_BAL_IDR  MTH6_AVG_BAL_IDR  \
# 0     8.539044e+06          -1.348543e+07     1.984331e+07      8.539044e+06
# 1     1.951391e+07           3.405224e+07     2.694370e+06      1.951391e+07
# 2     1.974608e+06           7.410419e+05     1.719333e+06      1.974608e+06
# 3     1.874303e+06           1.571728e+06     1.373424e+06      1.874303e+06
# 4     2.803859e+08           4.921136e+08     1.855625e+08      2.803859e+08
#
# ...

# %%
dfGender = Trset[["VTG"]]

# %%
dfGender.head()
# Out:
#         VTG
# 0  16-20 th
# 1  16-20 th
# 2  16-20 th
# 3  16-20 th
# 4  16-20 th

# %%
Trset = Trset.drop("AGETIER", axis=1)

# %%
Trset.head()
# Out:
#      CUST_NO       VTG EDUCATION_DESC   EOP_BAL_CS  MTH_AVG_BAL_CS  \
# 0  2730505.6  16-20 th    UNIVERSITAS  20560590.01    1.984331e+07
# 1  2734315.2  16-20 th    UNIVERSITAS    917094.84    2.694370e+06
# 2  2668305.2  16-20 th    UNIVERSITAS    430065.24    1.719333e+06
# 3  2526375.6  16-20 th    UNIVERSITAS   4348929.80    1.373424e+06
# 4  2437968.4  16-20 th            SMA  67022018.69    1.855625e+08
#
#    MTH6_AVG_BAL_CS  DELTA_FUNDING_BALANCE  MTH_AVG_BAL_IDR  MTH6_AVG_BAL_IDR  \
# 0     8.539044e+06          -1.348543e+07     1.984331e+07      8.539044e+06
# 1     1.951391e+07           3.405224e+07     2.694370e+06      1.951391e+07
# 2     1.974608e+06           7.410419e+05     1.719333e+06      1.974608e+06
# 3     1.874303e+06           1.571728e+06     1.373424e+06      1.874303e+06
# 4     2.803859e+08           4.921136e+08     1.855625e+08      2.803859e+08
#
#    DELTA_FUNDING_BALANCE_TD  AVG_CREDIT_3MTH  SUM_CREDIT_LESS_3MIL  \
# ...

# %%
Trset = pd.merge(dfGender, Trset, how='left', left_index=True, right_index=True)

# %%
Trset.head()
# Out:
#       VTG_x    CUST_NO     VTG_y EDUCATION_DESC   EOP_BAL_CS  MTH_AVG_BAL_CS  \
# 0  16-20 th  2730505.6  16-20 th    UNIVERSITAS  20560590.01    1.984331e+07
# 1  16-20 th  2734315.2  16-20 th    UNIVERSITAS    917094.84    2.694370e+06
# 2  16-20 th  2668305.2  16-20 th    UNIVERSITAS    430065.24    1.719333e+06
# 3  16-20 th  2526375.6  16-20 th    UNIVERSITAS   4348929.80    1.373424e+06
# 4  16-20 th  2437968.4  16-20 th            SMA  67022018.69    1.855625e+08
#
#    MTH6_AVG_BAL_CS  DELTA_FUNDING_BALANCE  MTH_AVG_BAL_IDR  MTH6_AVG_BAL_IDR  \
# 0     8.539044e+06          -1.348543e+07     1.984331e+07      8.539044e+06
# 1     1.951391e+07           3.405224e+07     2.694370e+06      1.951391e+07
# 2     1.974608e+06           7.410419e+05     1.719333e+06      1.974608e+06
# 3     1.874303e+06           1.571728e+06     1.373424e+06      1.874303e+06
# 4     2.803859e+08           4.921136e+08     1.855625e+08      2.803859e+08
#
# ...
